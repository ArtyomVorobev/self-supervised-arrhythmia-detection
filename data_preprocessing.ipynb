# %%
import os 
import wfdb
import ast
import pandas as pd 
import numpy as np 
from tqdm import tqdm
from sklearn.model_selection import train_test_split

pd.set_option('display.max_columns', None)

# %%
data_path = 'data'

# %%
annotation = pd.read_csv(os.path.join(data_path, 'ptbxl_database.csv'))
annotation.ecg_id -= 1

# %%
annotation.head()
# Out:
#    ecg_id  patient_id   age  sex  height  weight  nurse  site     device  \
# 0      -2     15709.0  56.0    1     NaN    63.0    2.0   0.0  CS-12   E
# 1      -1     13243.0  19.0    0     NaN    70.0    2.0   0.0  CS-12   E
# 2       0     20372.0  37.0    1     NaN    69.0    2.0   0.0  CS-12   E
# 3       1     17014.0  24.0    0     NaN    82.0    2.0   0.0  CS-12   E
# 4       2     17448.0  19.0    1     NaN    70.0    2.0   0.0  CS-12   E
#
#         recording_date                                  report  \
# 0  1984-11-09 09:17:34  sinusrhythmus periphere niederspannung
# 1  1984-11-14 12:55:37     sinusbradykardie sonst normales ekg
# 2  1984-11-15 12:49:10              sinusrhythmus normales ekg
# 3  1984-11-15 13:44:57              sinusrhythmus normales ekg
# 4  1984-11-17 10:43:15              sinusrhythmus normales ekg
#
#                                   scp_codes heart_axis infarction_stadium1  \
# 0  {'NORM': 100.0, 'LVOLT': 0.0, 'SR': 0.0}        NaN                 NaN
# 1              {'NORM': 80.0, 'SBRAD': 0.0}        NaN                 NaN
# 2                {'NORM': 100.0, 'SR': 0.0}        NaN                 NaN
# 3                {'NORM': 100.0, 'SR': 0.0}        NaN                 NaN
# 4                {'NORM': 100.0, 'SR': 0.0}        NaN                 NaN
#
#   infarction_stadium2  validated_by  second_opinion  \
# 0                 NaN           NaN           False
# 1                 NaN           NaN           False
# 2                 NaN           NaN           False
# 3                 NaN           NaN           False
# 4                 NaN           NaN           False
#
#    initial_autogenerated_report  validated_by_human  baseline_drift  \
# 0                         False                True             NaN
# 1                         False                True             NaN
# 2                         False                True             NaN
# 3                         False                True    , II,III,AVF
# 4                         False                True   , III,AVR,AVF
#
#   static_noise burst_noise electrodes_problems extra_beats pacemaker  \
# 0    , I-V1,           NaN                 NaN         NaN       NaN
# 1          NaN         NaN                 NaN         NaN       NaN
# 2          NaN         NaN                 NaN         NaN       NaN
# 3          NaN         NaN                 NaN         NaN       NaN
# 4          NaN         NaN                 NaN         NaN       NaN
#
#    strat_fold                filename_lr                filename_hr  \
# 0           3  records100/00000/00001_lr  records500/00000/00001_hr
# 1           2  records100/00000/00002_lr  records500/00000/00002_hr
# 2           5  records100/00000/00003_lr  records500/00000/00003_hr
# 3           3  records100/00000/00004_lr  records500/00000/00004_hr
# 4           4  records100/00000/00005_lr  records500/00000/00005_hr
#
#             rhythm_class  is_arrhytmia
# 0       ['sinus rhythm']             0
# 1  ['sinus bradycardia']             1
# 2       ['sinus rhythm']             0
# 3       ['sinus rhythm']             0
# 4       ['sinus rhythm']             0

# %%
annotation.shape
# Out:
# (21837, 30)

# %%
annotation.scp_codes = annotation.scp_codes.apply(lambda x: ast.literal_eval(x))

# %%
example_wf = os.path.join(data_path, annotation.iloc[0].filename_lr)

# %%
signal_data, meta_data = wfdb.rdsamp(example_wf)

# %%
signal_data
# Out:
# array([[-0.119, -0.055,  0.064, ..., -0.026, -0.039, -0.079],
#        [-0.116, -0.051,  0.065, ..., -0.031, -0.034, -0.074],
#        [-0.12 , -0.044,  0.076, ..., -0.028, -0.029, -0.069],
#        ...,
#        [ 0.069,  0.   , -0.069, ...,  0.024, -0.041, -0.058],
#        [ 0.086,  0.004, -0.081, ...,  0.242, -0.046, -0.098],
#        [ 0.022, -0.031, -0.054, ...,  0.143, -0.035, -0.12 ]])

# %%
signal_data.shape
# Out:
# (1000, 12)

# %%
signal_data[:, 0].shape
# Out:
# (1000,)

# %%
meta_data
# Out:
# {'fs': 100,
#  'sig_len': 1000,
#  'n_sig': 12,
#  'base_date': None,
#  'base_time': None,
#  'units': ['mV',
#   'mV',
#   'mV',
#   'mV',
#   'mV',
#   'mV',
#   'mV',
#   'mV',
#   'mV',
#   'mV',
#   'mV',
#   'mV'],
#  'sig_name': ['I',
#   'II',
#   'III',
#   'AVR',
#   'AVL',
#   'AVF',
#   'V1',
#   'V2',
#   'V3',
#   'V4',
#   'V5',
#   'V6'],
#  'comments': []}

# %%
meta_data['sig_name']
# Out:
# ['I', 'II', 'III', 'AVR', 'AVL', 'AVF', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6']

# %%
len(meta_data['sig_name'])
# Out:
# 12

# %%
def load_raw_data(df, sampling_rate, path):
    if sampling_rate == 100:
        data = [wfdb.rdsamp(os.path.join(path, file)) for file in tqdm(df.filename_lr)]
    else:
        data = [wfdb.rdsamp(os.path.join(path, file)) for file in tqdm(df.filename_hr)]
    
    data = np.array([signal for signal, meta in data])
    return data


sampling_rate=100

data = load_raw_data(annotation, sampling_rate, data_path)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 21837/21837 [07:41<00:00, 47.29it/s]

# %%
sample = data[0]

# %%
sample[:10, :]
# Out:
# array([[-0.119, -0.055,  0.064,  0.086, -0.091,  0.004, -0.069, -0.031,
#          0.   , -0.026, -0.039, -0.079],
#        [-0.116, -0.051,  0.065,  0.083, -0.09 ,  0.006, -0.064, -0.036,
#         -0.003, -0.031, -0.034, -0.074],
#        [-0.12 , -0.044,  0.076,  0.082, -0.098,  0.016, -0.058, -0.034,
#         -0.01 , -0.028, -0.029, -0.069],
#        [-0.117, -0.038,  0.08 ,  0.077, -0.098,  0.021, -0.05 , -0.03 ,
#         -0.015, -0.023, -0.022, -0.064],
#        [-0.103, -0.031,  0.072,  0.066, -0.087,  0.021, -0.045, -0.027,
#         -0.02 , -0.019, -0.018, -0.058],
#        [-0.097, -0.025,  0.071,  0.061, -0.084,  0.023, -0.036, -0.025,
#         -0.009, -0.014, -0.012, -0.052],
#        [-0.119, -0.014,  0.106,  0.066, -0.112,  0.046, -0.029, -0.012,
#          0.005, -0.008, -0.007, -0.048],
#        [-0.096,  0.008,  0.104,  0.044, -0.1  ,  0.056, -0.023,  0.003,
#          0.018,  0.002, -0.001, -0.041],
#        [-0.048,  0.044,  0.092,  0.002, -0.07 ,  0.068, -0.015,  0.018,
#          0.021,  0.009,  0.005, -0.038],
#        [-0.037,  0.045,  0.081, -0.004, -0.059,  0.063, -0.05 ,  0.009,
#          0.018,  0.022,  0.009, -0.033]])

# %%
np.save('signals.npy', data)

# %%
agg_df = pd.read_csv(os.path.join(data_path, 'scp_statements.csv'), index_col=0)
agg_df = agg_df[agg_df.rhythm == 1]

# %%
agg_df.head()
# Out:
#                description  diagnostic  form  rhythm diagnostic_class  \
# SR            sinus rhythm         NaN   NaN     1.0              NaN
# AFIB   atrial fibrillation         NaN   NaN     1.0              NaN
# STACH    sinus tachycardia         NaN   NaN     1.0              NaN
# SARRH     sinus arrhythmia         NaN   NaN     1.0              NaN
# SBRAD    sinus bradycardia         NaN   NaN     1.0              NaN
#
#       diagnostic_subclass                                 Statement Category  \
# SR                    NaN  Statements related to impulse formation (abnor...
# AFIB                  NaN  Statements related to impulse formation (abnor...
# STACH                 NaN  Statements related to impulse formation (abnor...
# SARRH                 NaN  Statements related to impulse formation (abnor...
# SBRAD                 NaN  Statements related to impulse formation (abnor...
#
#       SCP-ECG Statement Description  AHA code               aECG REFID  \
# SR                     sinus rhythm      20.0    MDC_ECG_RHY_SINUS_RHY
# AFIB            atrial fibrillation      50.0      MDC_ECG_RHY_ATR_FIB
# STACH             sinus tachycardia      21.0  MDC_ECG_RHY_SINUS_TACHY
# SARRH              sinus arrhythmia      23.0  MDC_ECG_RHY_SINUS_ARRHY
# SBRAD             sinus bradycardia      22.0  MDC_ECG_RHY_SINUS_BRADY
#
#       CDISC Code DICOM Code
# SR           NaN        NaN
# AFIB         NaN   D3-31520
# STACH        NaN        NaN
# SARRH        NaN        NaN
# SBRAD        NaN        NaN

# %%
rhythm_classes = set(agg_df.description.to_list())
normal_rhythm = set(['sinus rhythm', 'normal functioning artificial pacemaker'])
arrhytmia_classes = rhythm_classes - normal_rhythm

# %%
len(arrhytmia_classes)
# Out:
# 10

# %%
agg_df.shape
# Out:
# (12, 12)

# %%
def aggregate_rhythm(y_dic):
    tmp = []
    for key in y_dic.keys():
        if key in agg_df.index:
            tmp.append(agg_df.loc[key].description)
    return list(set(tmp))

# %%
annotation['rhythm_class'] = annotation.scp_codes.apply(aggregate_rhythm)

# %%
annotation.head()
# Out:
#    ecg_id  patient_id   age  sex  height  weight  nurse  site     device  \
# 0      -2     15709.0  56.0    1     NaN    63.0    2.0   0.0  CS-12   E
# 1      -1     13243.0  19.0    0     NaN    70.0    2.0   0.0  CS-12   E
# 2       0     20372.0  37.0    1     NaN    69.0    2.0   0.0  CS-12   E
# 3       1     17014.0  24.0    0     NaN    82.0    2.0   0.0  CS-12   E
# 4       2     17448.0  19.0    1     NaN    70.0    2.0   0.0  CS-12   E
#
#         recording_date                                  report  \
# 0  1984-11-09 09:17:34  sinusrhythmus periphere niederspannung
# 1  1984-11-14 12:55:37     sinusbradykardie sonst normales ekg
# 2  1984-11-15 12:49:10              sinusrhythmus normales ekg
# 3  1984-11-15 13:44:57              sinusrhythmus normales ekg
# 4  1984-11-17 10:43:15              sinusrhythmus normales ekg
#
#                                   scp_codes heart_axis infarction_stadium1  \
# 0  {'NORM': 100.0, 'LVOLT': 0.0, 'SR': 0.0}        NaN                 NaN
# 1              {'NORM': 80.0, 'SBRAD': 0.0}        NaN                 NaN
# 2                {'NORM': 100.0, 'SR': 0.0}        NaN                 NaN
# 3                {'NORM': 100.0, 'SR': 0.0}        NaN                 NaN
# 4                {'NORM': 100.0, 'SR': 0.0}        NaN                 NaN
#
#   infarction_stadium2  validated_by  second_opinion  \
# 0                 NaN           NaN           False
# 1                 NaN           NaN           False
# 2                 NaN           NaN           False
# 3                 NaN           NaN           False
# 4                 NaN           NaN           False
#
#    initial_autogenerated_report  validated_by_human  baseline_drift  \
# 0                         False                True             NaN
# 1                         False                True             NaN
# 2                         False                True             NaN
# 3                         False                True    , II,III,AVF
# 4                         False                True   , III,AVR,AVF
#
#   static_noise burst_noise electrodes_problems extra_beats pacemaker  \
# 0    , I-V1,           NaN                 NaN         NaN       NaN
# 1          NaN         NaN                 NaN         NaN       NaN
# 2          NaN         NaN                 NaN         NaN       NaN
# 3          NaN         NaN                 NaN         NaN       NaN
# 4          NaN         NaN                 NaN         NaN       NaN
#
#    strat_fold                filename_lr                filename_hr  \
# 0           3  records100/00000/00001_lr  records500/00000/00001_hr
# 1           2  records100/00000/00002_lr  records500/00000/00002_hr
# 2           5  records100/00000/00003_lr  records500/00000/00003_hr
# 3           3  records100/00000/00004_lr  records500/00000/00004_hr
# 4           4  records100/00000/00005_lr  records500/00000/00005_hr
#
#           rhythm_class  is_arrhytmia
# 0       [sinus rhythm]             0
# 1  [sinus bradycardia]             1
# 2       [sinus rhythm]             0
# 3       [sinus rhythm]             0
# 4       [sinus rhythm]             0

# %%
def get_target_column(row, arrhytmia_classes):
    cur_rhythm = set(row['rhythm_class'])
    
    normal_rhythm = set(['sinus rhythm', 'normal functioning artificial pacemaker'])
    if len(cur_rhythm & arrhytmia_classes) > 0:
        return 1 
    return 0

# %%
annotation.rhythm_class.value_counts()
# Out:
# [sinus rhythm]                                                                           16721
# [atrial fibrillation]                                                                     1484
# [sinus tachycardia]                                                                        805
# []                                                                                         771
# [sinus arrhythmia]                                                                         765
# [sinus bradycardia]                                                                        629
# [normal functioning artificial pacemaker]                                                  287
# [supraventricular arrhythmia]                                                              150
# [bigeminal pattern (unknown origin, SV or Ventricular), sinus rhythm]                       37
# [atrial flutter]                                                                            36
# [bigeminal pattern (unknown origin, SV or Ventricular)]                                     22
# [atrial fibrillation, atrial flutter]                                                       17
# [sinus tachycardia, bigeminal pattern (unknown origin, SV or Ventricular)]                  11
# [trigeminal pattern (unknown origin, SV or Ventricular), sinus rhythm]                      11
# [paroxysmal supraventricular tachycardia]                                                   10
# [supraventricular tachycardia]                                                              10
# [supraventricular tachycardia, paroxysmal supraventricular tachycardia]                      8
# [atrial fibrillation, bigeminal pattern (unknown origin, SV or Ventricular)]                 7
# [supraventricular tachycardia, atrial flutter]                                               6
# [sinus tachycardia, atrial flutter]                                                          5
# [atrial flutter, sinus rhythm]                                                               5
# [atrial fibrillation, normal functioning artificial pacemaker]                               4
# [trigeminal pattern (unknown origin, SV or Ventricular), sinus tachycardia]                  4
# [trigeminal pattern (unknown origin, SV or Ventricular)]                                     4
# [supraventricular arrhythmia, atrial flutter]                                                4
# [normal functioning artificial pacemaker, sinus rhythm]                                      3
# [bigeminal pattern (unknown origin, SV or Ventricular), sinus bradycardia]                   3
# [sinus arrhythmia, sinus bradycardia]                                                        3
# [normal functioning artificial pacemaker, sinus bradycardia]                                 2
# [sinus arrhythmia, sinus rhythm]                                                             2
# [sinus arrhythmia, bigeminal pattern (unknown origin, SV or Ventricular)]                    2
# [paroxysmal supraventricular tachycardia, supraventricular arrhythmia]                       2
# [paroxysmal supraventricular tachycardia, sinus rhythm]                                      1
# [sinus tachycardia, paroxysmal supraventricular tachycardia]                                 1
# [supraventricular tachycardia, sinus rhythm]                                                 1
# [supraventricular tachycardia, paroxysmal supraventricular tachycardia, sinus rhythm]        1
# [supraventricular tachycardia, atrial fibrillation]                                          1
# [trigeminal pattern (unknown origin, SV or Ventricular), supraventricular arrhythmia]        1
# [atrial fibrillation, paroxysmal supraventricular tachycardia]                               1
# Name: rhythm_class, dtype: int64

# %%
annotation['is_arrhytmia'] = annotation.apply(lambda row: get_target_column(row, arrhytmia_classes), axis=1)

# %%
annotation['is_arrhytmia'].value_counts()
# Out:
# 0    17782
# 1     4055
# Name: is_arrhytmia, dtype: int64

# %%
annotation.to_csv(os.path.join(data_path, 'ptbxl_database.csv'), index=False)

# %% [markdown]
# # train test split

# %%
TEST_SIZE = 0.25

# %%
target = annotation['is_arrhytmia'].to_numpy()

# %%
np.save(os.path.join(data_path, 'target.npy'), target)

# %%
X_train, X_test, y_train, y_test = train_test_split(data, target, test_size=TEST_SIZE, random_state=42)

# %%
np.save(os.path.join(data_path, 'train_data.npy'), X_train)
np.save(os.path.join(data_path, 'train_target.npy'), y_train) 
            
np.save(os.path.join(data_path, 'test_data.npy'), X_test)
np.save(os.path.join(data_path, 'test_target.npy'), y_test)
